# %% [markdown]
# <a href="https://colab.research.google.com/github/IS-Saja/DataScienceProject/blob/master/Python_Code/Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Welcome to Data Science Project")
print("Student: Saja")
print("This repository is for AI Master's assignments.")
# Out:
# Welcome to Data Science Project
# Student: Saja
# This repository is for AI Master's assignments.

# %% [markdown]
# ### DataFrame

# %%
import pandas as pd

data = {
    'Topic': ['Data Cleaning', 'Visualization', 'Modeling'],
    'Progress': ['Completed', 'In Progress', 'Planned']
}

df = pd.DataFrame(data)
print("Data Science Topics Status:")
print(df)
# Out:
# Data Science Topics Status:
#            Topic     Progress
# 0  Data Cleaning    Completed
# 1  Visualization  In Progress
# 2       Modeling      Planned

# %%
import numpy as np

scores = [85, 90, 78, 92, 88]
mean_score = np.mean(scores)

print(f"Data Analysis Result:")
print(f"The average score is: {mean_score}")
# Out:
# Data Analysis Result:
# The average score is: 86.6
